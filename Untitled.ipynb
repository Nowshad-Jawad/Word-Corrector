# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
    with open(filename,"r") as file:
        lines = file.readlines()
        words = []
        
        for line in lines:
            words += re.findall(r'\w+', line.lower())
            
    return words

# %%
words = read_corpus(".\hamlet.txt")

# %%
print(len(words))
# Out:
# 32884

# %%
vocabs = set(words)
print(len(vocabs))
# Out:
# 4606

# %%
words_count = Counter(words)
print(words_count["fire"])
# Out:
# 12

# %%
total_word_count = float(sum(words_count.values()))
word_prob = {word: words_count[word] / total_word_count for word in words_count.keys()}

# %%
print(word_prob["fire"])
# Out:
# 0.0003649191095973726

# %%
def split(word):
    return[(word[:i], word[i:]) for i in range(len(word)+1)]

# %%
print(split("grammar"))
# Out:
# [('', 'grammar'), ('g', 'rammar'), ('gr', 'ammar'), ('gra', 'mmar'), ('gram', 'mar'), ('gramm', 'ar'), ('gramma', 'r'), ('grammar', '')]

# %%
def delete(word):
    return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("grammar"))
# Out:
# ['rammar', 'gammar', 'grmmar', 'gramar', 'gramar', 'grammr', 'gramma']

# %%
def swap(word):
    return [l + r[1] + r[0] + r[2:] for l,r in split(word) if len(r)>1]

# %%
print(swap("grammar"))
# Out:
# ['rgammar', 'garmmar', 'grmamar', 'grammar', 'gramamr', 'grammra']

# %%
def replace(word):
    letters = string.ascii_lowercase
    return [l + c + r[1:] for l,r in split(word) if r for c in letters]

# %%
print(replace("grammar"))
# Out:
# ['arammar', 'brammar', 'crammar', 'drammar', 'erammar', 'frammar', 'grammar', 'hrammar', 'irammar', 'jrammar', 'krammar', 'lrammar', 'mrammar', 'nrammar', 'orammar', 'prammar', 'qrammar', 'rrammar', 'srammar', 'trammar', 'urammar', 'vrammar', 'wrammar', 'xrammar', 'yrammar', 'zrammar', 'gaammar', 'gbammar', 'gcammar', 'gdammar', 'geammar', 'gfammar', 'ggammar', 'ghammar', 'giammar', 'gjammar', 'gkammar', 'glammar', 'gmammar', 'gnammar', 'goammar', 'gpammar', 'gqammar', 'grammar', 'gsammar', 'gtammar', 'guammar', 'gvammar', 'gwammar', 'gxammar', 'gyammar', 'gzammar', 'grammar', 'grbmmar', 'grcmmar', 'grdmmar', 'gremmar', 'grfmmar', 'grgmmar', 'grhmmar', 'grimmar', 'grjmmar', 'grkmmar', 'grlmmar', 'grmmmar', 'grnmmar', 'grommar', 'grpmmar', 'grqmmar', 'grrmmar', 'grsmmar', 'grtmmar', 'grummar', 'grvmmar', 'grwmmar', 'grxmmar', 'grymmar', 'grzmmar', 'graamar', 'grabmar', 'gracmar', 'gradmar', 'graemar', 'grafmar', 'gragmar', 'grahmar', 'graimar', 'grajmar', 'grakmar', 'gralmar', 'grammar', 'granmar', 'graomar', 'grapmar', 'graqmar', 'grarmar', 'grasmar', 'gratmar', 'graumar', 'gravmar', 'grawmar', 'graxmar', 'graymar', 'grazmar', 'gramaar', 'grambar', 'gramcar', 'gramdar', 'gramear', 'gramfar', 'gramgar', 'gramhar', 'gramiar', 'gramjar', 'gramkar', 'gramlar', 'grammar', 'gramnar', 'gramoar', 'grampar', 'gramqar', 'gramrar', 'gramsar', 'gramtar', 'gramuar', 'gramvar', 'gramwar', 'gramxar', 'gramyar', 'gramzar', 'grammar', 'grammbr', 'grammcr', 'grammdr', 'grammer', 'grammfr', 'grammgr', 'grammhr', 'grammir', 'grammjr', 'grammkr', 'grammlr', 'grammmr', 'grammnr', 'grammor', 'grammpr', 'grammqr', 'grammrr', 'grammsr', 'grammtr', 'grammur', 'grammvr', 'grammwr', 'grammxr', 'grammyr', 'grammzr', 'grammaa', 'grammab', 'grammac', 'grammad', 'grammae', 'grammaf', 'grammag', 'grammah', 'grammai', 'grammaj', 'grammak', 'grammal', 'grammam', 'gramman', 'grammao', 'grammap', 'grammaq', 'grammar', 'grammas', 'grammat', 'grammau', 'grammav', 'grammaw', 'grammax', 'grammay', 'grammaz']

# %%
def insert(word):
    letters = string.ascii_lowercase
    return [l + c + r for l,r in split(word) for c in letters]

# %%
print(insert("grammar"))
# Out:
# ['agrammar', 'bgrammar', 'cgrammar', 'dgrammar', 'egrammar', 'fgrammar', 'ggrammar', 'hgrammar', 'igrammar', 'jgrammar', 'kgrammar', 'lgrammar', 'mgrammar', 'ngrammar', 'ogrammar', 'pgrammar', 'qgrammar', 'rgrammar', 'sgrammar', 'tgrammar', 'ugrammar', 'vgrammar', 'wgrammar', 'xgrammar', 'ygrammar', 'zgrammar', 'garammar', 'gbrammar', 'gcrammar', 'gdrammar', 'gerammar', 'gframmar', 'ggrammar', 'ghrammar', 'girammar', 'gjrammar', 'gkrammar', 'glrammar', 'gmrammar', 'gnrammar', 'gorammar', 'gprammar', 'gqrammar', 'grrammar', 'gsrammar', 'gtrammar', 'gurammar', 'gvrammar', 'gwrammar', 'gxrammar', 'gyrammar', 'gzrammar', 'graammar', 'grbammar', 'grcammar', 'grdammar', 'greammar', 'grfammar', 'grgammar', 'grhammar', 'griammar', 'grjammar', 'grkammar', 'grlammar', 'grmammar', 'grnammar', 'groammar', 'grpammar', 'grqammar', 'grrammar', 'grsammar', 'grtammar', 'gruammar', 'grvammar', 'grwammar', 'grxammar', 'gryammar', 'grzammar', 'graammar', 'grabmmar', 'gracmmar', 'gradmmar', 'graemmar', 'grafmmar', 'gragmmar', 'grahmmar', 'graimmar', 'grajmmar', 'grakmmar', 'gralmmar', 'grammmar', 'granmmar', 'graommar', 'grapmmar', 'graqmmar', 'grarmmar', 'grasmmar', 'gratmmar', 'graummar', 'gravmmar', 'grawmmar', 'graxmmar', 'graymmar', 'grazmmar', 'gramamar', 'grambmar', 'gramcmar', 'gramdmar', 'gramemar', 'gramfmar', 'gramgmar', 'gramhmar', 'gramimar', 'gramjmar', 'gramkmar', 'gramlmar', 'grammmar', 'gramnmar', 'gramomar', 'grampmar', 'gramqmar', 'gramrmar', 'gramsmar', 'gramtmar', 'gramumar', 'gramvmar', 'gramwmar', 'gramxmar', 'gramymar', 'gramzmar', 'grammaar', 'grammbar', 'grammcar', 'grammdar', 'grammear', 'grammfar', 'grammgar', 'grammhar', 'grammiar', 'grammjar', 'grammkar', 'grammlar', 'grammmar', 'grammnar', 'grammoar', 'grammpar', 'grammqar', 'grammrar', 'grammsar', 'grammtar', 'grammuar', 'grammvar', 'grammwar', 'grammxar', 'grammyar', 'grammzar', 'grammaar', 'grammabr', 'grammacr', 'grammadr', 'grammaer', 'grammafr', 'grammagr', 'grammahr', 'grammair', 'grammajr', 'grammakr', 'grammalr', 'grammamr', 'grammanr', 'grammaor', 'grammapr', 'grammaqr', 'grammarr', 'grammasr', 'grammatr', 'grammaur', 'grammavr', 'grammawr', 'grammaxr', 'grammayr', 'grammazr', 'grammara', 'grammarb', 'grammarc', 'grammard', 'grammare', 'grammarf', 'grammarg', 'grammarh', 'grammari', 'grammarj', 'grammark', 'grammarl', 'grammarm', 'grammarn', 'grammaro', 'grammarp', 'grammarq', 'grammarr', 'grammars', 'grammart', 'grammaru', 'grammarv', 'grammarw', 'grammarx', 'grammary', 'grammarz']

# %%
def level_one_edits(word):
    return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(level_one_edits("grammar"))
# Out:
# {'grammarp', 'grlmmar', 'grammagr', 'grawmmar', 'grahmmar', 'gramqar', 'graimar', 'gramyar', 'gramgmar', 'grammpar', 'grammabr', 'grammmar', 'grcmmar', 'grammrar', 'ggammar', 'grammlar', 'gtrammar', 'grammavr', 'grammark', 'grxammar', 'grvmmar', 'gramuar', 'grajmmar', 'gramzar', 'gravmmar', 'gnammar', 'grasmar', 'gpammar', 'erammar', 'grammasr', 'wrammar', 'grmamar', 'gramcar', 'grammahr', 'grammay', 'grammdar', 'gramamr', 'grwmmar', 'xrammar', 'grammfar', 'grammary', 'gramwar', 'gbrammar', 'grqmmar', 'grdmmar', 'grammari', 'zgrammar', 'grammuar', 'grammpr', 'grammkr', 'grammad', 'grsmmar', 'grapmmar', 'grmmar', 'glrammar', 'ghrammar', 'gramoar', 'gramhar', 'grammacr', 'grammarc', 'grammoar', 'gramxar', 'guammar', 'gramzmar', 'grammanr', 'kgrammar', 'grimmar', 'xgrammar', 'gramrmar', 'grammhr', 'grawmar', 'crammar', 'graamar', 'fgrammar', 'ngrammar', 'grammarm', 'grammafr', 'grabmar', 'garammar', 'srammar', 'grammarj', 'gramjar', 'gramomar', 'grammakr', 'grammgr', 'grammnar', 'grampar', 'gqrammar', 'grammard', 'vgrammar', 'greammar', 'gvammar', 'grammiar', 'dgrammar', 'gramjmar', 'grammaa', 'grammvr', 'grnammar', 'grammqar', 'gvrammar', 'grbmmar', 'grmammar', 'grammaj', 'gkammar', 'grambmar', 'grammir', 'grammaqr', 'grpmmar', 'graimmar', 'grahmar', 'ugrammar', 'grjmmar', 'krammar', 'gramkar', 'graumar', 'grazmmar', 'gjammar', 'graammar', 'graymmar', 'gramlar', 'gerammar', 'gramimar', 'gramdmar', 'griammar', 'gramma', 'gorammar', 'granmmar', 'grammaar', 'grammarw', 'grammsr', 'gkrammar', 'grafmmar', 'grammav', 'grtammar', 'grammarz', 'ggrammar', 'gurammar', 'gmrammar', 'gaammar', 'grammarl', 'grammarh', 'grammxr', 'pgrammar', 'gjrammar', 'grammam', 'gcammar', 'tgrammar', 'grqammar', 'grasmmar', 'gramvmar', 'egrammar', 'glammar', 'jrammar', 'grammarn', 'grammtr', 'grammqr', 'grammab', 'gramkmar', 'gramfar', 'grammzar', 'gramrar', 'grfammar', 'gramsar', 'grammarr', 'grmmmar', 'frammar', 'gbammar', 'vrammar', 'graqmar', 'grammat', 'gramlmar', 'grammarg', 'grammax', 'graqmmar', 'graxmmar', 'gramgar', 'granmar', 'gramnmar', 'grammvar', 'grammajr', 'grammbr', 'mgrammar', 'gramaar', 'gryammar', 'gramtar', 'grammatr', 'gragmar', 'ygrammar', 'grammjar', 'grammamr', 'gramemar', 'gralmar', 'gramfmar', 'gramsmar', 'grammhar', 'grammac', 'geammar', 'gyammar', 'graemar', 'grampmar', 'grammalr', 'graymar', 'grammas', 'grammcr', 'grammaor', 'grammkar', 'grkmmar', 'qrammar', 'grammare', 'grammap', 'grjammar', 'gragmmar', 'gdammar', 'graomar', 'grammag', 'grammzr', 'grammaxr', 'grammal', 'grammara', 'gramar', 'hgrammar', 'grarmar', 'gramdar', 'grymmar', 'gramwmar', 'grgmmar', 'grammair', 'graummar', 'grwammar', 'gremmar', 'grammawr', 'grammaru', 'grammarb', 'gprammar', 'grakmmar', 'gwammar', 'grabmmar', 'groammar', 'grammak', 'grafmar', 'grhmmar', 'grpammar', 'grcammar', 'gracmmar', 'grammart', 'grammai', 'gramqmar', 'rgammar', 'gramman', 'grammao', 'grammae', 'graxmar', 'hrammar', 'urammar', 'jgrammar', 'gqammar', 'grammcar', 'gratmmar', 'arammar', 'grammaq', 'grammr', 'grvammar', 'gratmar', 'gyrammar', 'grammnr', 'ghammar', 'graemmar', 'sgrammar', 'grammbar', 'grrammar', 'grammer', 'gramvar', 'grammarf', 'gzrammar', 'grammsar', 'grammor', 'grtmmar', 'gammar', 'rrammar', 'orammar', 'bgrammar', 'grammyr', 'grammjr', 'grammtar', 'grzammar', 'trammar', 'grxmmar', 'grammayr', 'gdrammar', 'grzmmar', 'grazmar', 'grfmmar', 'grammarq', 'gradmmar', 'grajmar', 'grammaw', 'grkammar', 'grgammar', 'nrammar', 'grammarv', 'graommar', 'grammwr', 'gramymar', 'grammaro', 'drammar', 'gsammar', 'grammau', 'grammaf', 'grammmr', 'gruammar', 'grakmar', 'grammapr', 'grammarx', 'grammra', 'grarmmar', 'gramnar', 'grammadr', 'gzammar', 'gnrammar', 'grammars', 'grrmmar', 'grlammar', 'gradmar', 'gramamar', 'gramumar', 'wgrammar', 'grambar', 'gcrammar', 'lgrammar', 'igrammar', 'irammar', 'giammar', 'grhammar', 'grammyar', 'grbammar', 'grammear', 'gravmar', 'grnmmar', 'grammah', 'lrammar', 'gramhmar', 'gramiar', 'ogrammar', 'qgrammar', 'gmammar', 'prammar', 'gframmar', 'gxam ...

# %%
def level_two_edits(word):
    return set(e2 for e1 in level_one_edits(word) for e2 in level_one_edits(e1))

# %%
print(level_two_edits("grammar"))
# Out:
# {'grampmcar', 'xgrqammar', 'zgragmmar', 'kgrazmmar', 'griaummar', 'ygurammar', 'gramgmah', 'grzmmoar', 'gkriammar', 'greammpar', 'grajmmabr', 'orammafr', 'grabmas', 'grgdammar', 'grlaommar', 'grafqmmar', 'ggrammap', 'gzymmar', 'gsrammal', 'grarmart', 'gramymgar', 'gyrammad', 'gvammab', 'wfgrammar', 'gvravmar', 'gramkaer', 'gfammtar', 'gravfmmar', 'grbammat', 'gramfmwar', 'grsmmpar', 'agrammyar', 'grammatar', 'grammmacr', 'grlmmaa', 'girammkar', 'grmmcar', 'grammwamr', 'egrammkar', 'graemtmar', 'gramemcar', 'dgralmar', 'graqmmvar', 'hgrammuar', 'grazmmkr', 'grvmmac', 'gjrymmar', 'giamzar', 'grpmhar', 'grammrru', 'gramjkar', 'gratmakr', 'grpqmar', 'grkaxmmar', 'grakmajr', 'gxaxmar', 'gvammlar', 'gwammau', 'grammuard', 'gjrammai', 'gxramamar', 'grhasmar', 'gzammvr', 'gyawmmar', 'grcammir', 'grammwjr', 'rgrammiar', 'dramsmar', 'tgrammlar', 'grommiar', 'grammkarq', 'gmammadr', 'fjrammar', 'gprammzr', 'gractar', 'gramiaor', 'gfamyar', 'gramrak', 'grhmmbar', 'gkrammarp', 'gcammah', 'rgammgr', 'pgrammair', 'grammewar', 'gewmmar', 'lrhammar', 'grjammawr', 'grpwmar', 'pgramrmar', 'gramgab', 'gramaarb', 'arammarp', 'grailmmar', 'zgramwar', 'czrammar', 'gtamamr', 'gfamlmar', 'gramwat', 'egryammar', 'gbrammart', 'vzgrammar', 'grlmmsr', 'gvrhammar', 'graolar', 'trammsr', 'gramiair', 'gsrammarq', 'wgrammat', 'gramamazr', 'gwamoar', 'igrammra', 'grpwmmar', 'grgmmair', 'cgrabmar', 'greammpr', 'urammlar', 'ygdammar', 'qgrammhar', 'gramrmart', 'grbmsar', 'yrammtr', 'grammary', 'gwramdmar', 'grzambmar', 'grammaczr', 'grjrmmar', 'larammar', 'franmmar', 'gmgrammar', 'graammari', 'pgraqmar', 'ygyammar', 'grammfadr', 'graymbr', 'groammafr', 'gsammagr', 'fgraimar', 'grhamjar', 'graxmmaar', 'grzammrr', 'grammlap', 'gpkammar', 'irammax', 'greaxmmar', 'gramura', 'irymmar', 'goamamar', 'erammalr', 'grammhsar', 'tramcmar', 'grawmxar', 'pracmar', 'guramvmar', 'vzrammar', 'gramkaw', 'grammlrh', 'gramqmajr', 'grolmar', 'grammakro', 'grajmemar', 'grammmary', 'grafmjar', 'gtammao', 'pgramjmar', 'gwamfmar', 'grammpaf', 'grqaimar', 'wrammlar', 'graimawr', 'gramtmax', 'guammak', 'agprammar', 'ghmrammar', 'egwrammar', 'grammacvr', 'grammgarp', 'grammarrz', 'grammhr', 'grampimar', 'ogrammxar', 'garmmaer', 'gravzar', 'greammbar', 'grxammav', 'gxgmmar', 'grrammgar', 'gprammajr', 'graamdr', 'lgrammak', 'kraimar', 'pgrjmmar', 'gmrammaf', 'garmmer', 'gramdarf', 'grammcrf', 'dgramear', 'pgerammar', 'grammarlt', 'grammom', 'gramaaw', 'gcamdar', 'gnramvmar', 'gramgarh', 'amgrammar', 'grajmqar', 'grymmarf', 'rgrammaw', 'graammwr', 'mrawmmar', 'gmammgr', 'graemma', 'grarmawr', 'graommart', 'gakrammar', 'orammax', 'grvammav', 'gmamkar', 'grammdalr', 'tgramxar', 'gvraymar', 'gramtmarl', 'krammer', 'rammare', 'gtammwr', 'graimmkar', 'mrammacr', 'grazmaj', 'gratmma', 'ghrammarg', 'gwramlmar', 'grammgarf', 'grxabmmar', 'grkammfr', 'gnramfmar', 'gramcmarf', 'grqammars', 'grabmvmar', 'grkmmam', 'grammgra', 'gtagmar', 'grammuay', 'gramduar', 'grarmafr', 'grafmmarq', 'wgrammoar', 'guimmar', 'grmamal', 'grtammarz', 'rrfammar', 'grajmzmar', 'zgrjammar', 'grpamnar', 'gsrambar', 'agrammaw', 'xgramqmar', 'gramemacr', 'grammakar', 'gvawmmar', 'rgrlmmar', 'granfar', 'grfmmarz', 'grammjaar', 'grammfvar', 'gramdmagr', 'grvhmar', 'grammhfr', 'goamlar', 'ggragmar', 'jcammar', 'grammwry', 'grakgmmar', 'kgraxmmar', 'craammar', 'grammcan', 'grdmmfr', 'gjeammar', 'gjaummar', 'gpramcmar', 'gramkac', 'grmamxar', 'gramqor', 'grqmxar', 'bgrasmmar', 'gradmmjr', 'gramjmdar', 'ggrammur', 'grajmmkar', 'grammll', 'grammaprf', 'graqwmar', 'vgrammarg', 'gramamarv', 'grammlai', 'grummay', 'cradmmar', 'ogramxmar', 'gkraimmar', 'grgammarn', 'grbcmar', 'grwaimmar', 'tgraxmmar', 'grdavmmar', 'gvrammaqr', 'grammafv', 'ggakmar', 'grmammnar', 'graammtar', 'grawmac', 'yggrammar', 'gsramar', 'kgrammaj', 'grammaxrq', 'mrvammar', 'grammgor', 'krkmmar', 'grawsmar', 'graymlr', 'garaqmar', 'grqmqmar', 'qrpmmar', 'grafmmlar', 'vgammar', 'geamcar', 'gracmmau', 'gramladr', 'gramnagr', 'gromjar', 'graclmar', 'gmoammar', 'grhmlma ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
    if word in vocabulary:
        print("correctly spelled")
        return
    else:
        suggestion = level_one_edits(word) or level_two_edits(word) or [word]
        best_guess = [w for w in suggestion if w in vocabulary]
        return [(w, word_probabilities[w]) for w in best_guess]

# %%
word = "ford"
guess = correct_spelling(word, vocabs, word_prob)

print(guess)
# Out:
# [('for', 0.007663301301544824), ('forg', 3.040992579978105e-05), ('fort', 0.0001824595547986863), ('lord', 0.006872643230750517), ('forc', 6.08198515995621e-05), ('word', 0.0003649191095973726), ('form', 0.0003953290353971536), ('fore', 3.040992579978105e-05), ('food', 6.08198515995621e-05), ('fordo', 3.040992579978105e-05), ('fond', 3.040992579978105e-05)]

# %%
class SpellChecker(object):
    
    def __init__(self, corpus_file_path):
        with open(corpus_file_path, "r") as file:
            lines = file.readlines()
            words=[]
            
            for line in lines:
                words += re.findall(r'\w+', line.lower())
                
            self.vocabs= set(words)
            self.word_counts = Counter(words)
            total_word_count = float(sum(words_count.values()))
            self.word_prob = {word: self.word_counts[word] / total_word_count for word in self.vocabs}
            
     
    def level_one_edits(self, word):
        letters = string.ascii_lowercase
        splits = [(word[:i], word[i:]) for i in range(len(word)+1)]
        deletes = [l + r[1:] for l,r in split(word) if r]
        swaps = [l + r[1] + r[0] + r[2:] for l,r in split(word) if len(r)>1]
        replaces = [l + c + r[1:] for l,r in split(word) if r for c in letters]
        inserts = [l + c + r for l,r in split(word) for c in letters]
        
        return set(deletes + swaps + replaces + inserts)
    
    
    def level_two_edits(self, word):
        return set((e2 for e1 in level_one_edits(word) for e2 in level_one_edits(e1)))
    
    def check(self, word):
        if word in self.vocabs:
            print("Correctly Spelled")
            return
        print("Incorrectly Spelled. Suggestions:")
        candidates = self.level_one_edits(word) or self.level_two_edits(word) or [word]
        valid_candidates = [w for w in candidates if w in self.vocabs]
        return sorted([(c) for c in valid_candidates], key=lambda tup:tup[1], reverse=True)

# %%
checker= SpellChecker(".\hamlet.txt")

# %%
m_word= "grammar"
print(checker.check(m_word))
# Out:
# Incorrectly Spelled. Suggestions:
# []
